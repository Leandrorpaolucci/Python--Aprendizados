# %%
# Criar um navegador biblioteca selenium
#------------------------------------------#
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
#------------------------------------------#
import pandas as pd
#------------------------------------------#
navegador = webdriver.Chrome()

# importar/visualizar a base de dados
tabela_produtos = pd.read_excel(r"Projeto 2 - Google Shopping e Buscape\buscas.xlsx")
#display(tabela_produtos)

# %%
# Entrar no google
navegador.get("https://www.google.com.br/")

produto = 'iphone 12 64gb'
# pesquisar o nome do produto no google
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(produto)
navegador.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)
# clicar na aba shopping
elementos = navegador.find_elements(By.CLASS_NAME, 'hdtb-mitem')
for item in elementos:
    if "Shopping" in item.text:
        item.click()
        break
# pegar o preço do produto no shopping
lista_resultados = navegador.find_elements(By.CLASS_NAME, 'sh-dgr__grid-result')
for resultado in lista_resultados:
    preco = resultado.find_element(By.CLASS_NAME, 'XrAfOe').text
    nome = resultado.find_element(By.CLASS_NAME, 'tAxDx').text
    link = resultado.find_element(By.CLASS_NAME, 'shntl').get_attribute('href')
    print(preco, nome, link)
    
# Para cada item dentro da nossa base de dados (para cada produto)
    #procurar esse produto no google shopping
        #verificar se algum dos produtos do google shopping esta dentro da minha base de preço
    #procurar esse produto no buscapé
        #verificar se algum dos produtos do buscapé esta dentro da minha base de preço
        
#Salvar as ofertas boas em um dataframe (tabela)
#expotar para o excel
# enviar por e-mail o resultado da tabela
# Out:
#   None
# R$ 3.099,00
# R$ 3.099,00. Smartphone Apple iPhone 12 64GB iOS Azul None
# R$ 2.700,00 R$ 3.399,00
# R$ 2.700,00 Custava R$ 3.399,00. iPhone 12 64gb Preto Vitrine None
# R$ 3.999,00
# R$ 3.999,00. iPhone 12 Apple (64GB) Verde, Tela De 6,1, 5G E Câmera Dupla De 12 Mp None
# R$ 4.364,03
# R$ 4.364,03. Smartphone Apple iPhone 12 64GB iOS Verde None
# R$ 3.899,00
# R$ 3.899,00.
# Usado Vitrine: iPhone 12 Apple 64GB Azul Tela 6,1 Câmera Traseira Dupla 12MP None
# R$ 4.439,00
# R$ 4.439,00.
# Usado Vitrine: iPhone 12 Apple 64GB Preto Tela 6,1 Câmera Traseira Dupla 12MP Ios None
# R$ 3.999,00
# R$ 3.999,00. iPhone 12 64GB - Preto None
# R$ 2.700,00 R$ 3.399,00
# R$ 2.700,00 Custava R$ 3.399,00. iPhone 12 64gb Branco Vitrine None
# R$ 2.800,00
# R$ 2.800,00.
# Usado IPHONE 12 64GB None
# R$ 2.700,00 R$ 3.399,00
# R$ 2.700,00 Custava R$ 3.399,00. iPhone 12 64gb Roxo Vitrine None
