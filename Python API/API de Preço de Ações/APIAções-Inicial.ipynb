# %% [markdown]
# ### Alpha Vantage
#
# https://www.alphavantage.co/documentation/

# %% [markdown]
# #### Pegando cotações semanais - JSON

# %%
from chave import chave_api

import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=GOOG&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'Meta Data': {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes', '2. Symbol': 'GOOG', '3. Last Refreshed': '2022-10-31', '4. Time Zone': 'US/Eastern'}, 'Monthly Time Series': {'2022-10-31': {'1. open': '97.2200', '2. high': '105.0999', '3. low': '91.9000', '4. close': '94.6600', '5. volume': '584616310'}, '2022-09-30': {'1. open': '109.2000', '2. high': '112.6400', '3. low': '96.0300', '4. close': '96.1500', '5. volume': '532842467'}, '2022-08-31': {'1. open': '115.5300', '2. high': '123.2600', '3. low': '108.8000', '4. close': '109.1500', '5. volume': '430922710'}, '2022-07-29': {'1. open': '2166.7400', '2. high': '2408.7000', '3. low': '104.7600', '4. close': '116.6400', '5. volume': '339525726'}, '2022-06-30': {'1. open': '2298.6300', '2. high': '2387.9696', '3. low': '2112.5706', '4. close': '2187.4500', '5. volume': '31358279'}, '2022-05-31': {'1. open': '2278.1300', '2. high': '2462.8600', '3. low': '2044.1600', '4. close': '2280.7800', '5. volume': '35869499'}, '2022-04-29': {'1. open': '2800.2000', '2. high': '2880.8750', '3. low': '2262.4850', '4. close': '2299.3300', '5. volume': '28022017'}, '2022-03-31': {'1. open': '2689.6000', '2. high': '2883.2500', '3. low': '2517.2150', '4. close': '2792.9900', '5. volume': '31811236'}, '2022-02-28': {'1. open': '2756.7000', '2. high': '3042.0000', '3. low': '2495.2900', '4. close': '2697.8200', '5. volume': '36609705'}, '2022-01-31': {'1. open': '2889.5100', '2. high': '2932.2000', '3. low': '2492.8390', '4. close': '2713.9700', '5. volume': '30699124'}, '2021-12-31': {'1. open': '2884.2500', '2. high': '2992.1000', '3. low': '2805.0000', '4. close': '2893.5900', '5. volume': '23950206'}, '2021-11-30': {'1. open': '2963.3000', '2. high': '3037.0000', '3. low': '2841.3200', '4. close': '2849.0400', '5. volume': '22120136'}, '2021-10-29': {'1. open': '2671.0900', '2. high': '2982.3600', '3. low': '2623.3300', '4. close': '2965.4100', '5. volume': '24830507'}, '2021-09-30': {'1. open': '2913.0000', '2. high': '2936.4099', '3. low': '2660.0000', '4. close': '2665.3100', '5. volume': '25265626'}, '2021-08-31': {'1. open': '2709.6900', '2. high': '2929.7899', '3. low': '2683.6700', '4. close': '2909.2400', '5. volume': '18615809'}, '2021-07-30': {'1. open': '2496.9950', '2. high': '2800.2200', '3. low': '2496.9950', '4. close': '2704.4200', '5. volume': '22824857'}, '2021-06-30': {'1. open': '2422.0000', '2. high': '2555.9200', '3. low': '2382.8300', '4. close': '2506.3200', '5. volume': '27425377'}, '2021-05-28': {'1. open': '2402.7200', '2. high': '2442.9440', '3. low': '2230.0500', '4. close': '2411.5600', '5. volume': '25456404'}, '2021-04-30': {'1. open': '2097.9500', '2. high': '2452.3780', '3. low': '2096.8900', '4. close': '2410.1200', '5. volume': '30727072'}, '2021-03-31': {'1. open': '2056.5200', '2. high': '2128.8100', '3. low': '2010.0000', '4. close': '2068.6300', '5. volume': '34796574'}, '2021-02-26': {'1. open': '1853.5700', '2. high': '2152.6800', '3. low': '1850.9300', '4. close': '2036.8600', '5. volume': '29111908'}, '2021-01-29': {'1. open': '1757.5400', '2. high': '1934.8600', '3. low': '1699.0000', '4. close': '1835.7400', '5. volume': '33082794'}, '2020-12-31': {'1. open': '1774.3700', '2. high': '1847.2000', '3. low': '1699.0000', '4. close': '1751.8800', '5. volume': '31422606'}, '2020-11-30': {'1. open': '1628.1600', '2. high': '1818.0600', '3. low': '1616.0300', '4. close': '1760.7400', '5. volume': '34952246'}, '2020-10-30': {'1. open': '1484.2700', '2. high': '1687.0000', '3. low': '1436.0000', '4. close': '1621.0100', '5. volume': '39260343'}, '2020-09-30': {'1. open': '1636.6300', '2. high': '1733.1799', '3. low': '1406.5500', '4. close': '1469.6000', '5. volume': '40570621'}, '2020-08-31': {'1. open': '1486.6400', '2. high': '1659.2200', '3. low': '1458.6500', '4. close': '1634.1800', '5. volume': '37293396'}, '2020-07-31': {'1. open': '1411.1000', '2. high': '1586.9900', '3. low': '1409.8200', '4. close': '1482.9600', '5. vo ...

# %% [markdown]
# #### Pegando cotações semanais - CSV

# %%
import pandas as pd
# ele pega um texto e transforma um texto no arquivo
from io import StringIO
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol=GOOG&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#       timestamp     open       high        low    close     volume
# 0    2022-10-14    97.22   103.7300    95.2700    97.18  218230731
# 1    2022-09-30   109.20   112.6400    96.0300    96.15  532842467
# 2    2022-08-31   115.53   123.2600   108.8000   109.15  430922710
# 3    2022-07-29  2166.74  2408.7000   104.7600   116.64  339525726
# 4    2022-06-30  2298.63  2387.9696  2112.5706  2187.45   31358279
# ..          ...      ...        ...        ...      ...        ...
# 98   2014-08-29   570.40   587.3400   560.0000   571.60   27586000
# 99   2014-07-31   578.32   599.6500   565.0100   571.60   34516100
# 100  2014-06-30   560.70   582.4500   538.7500   575.28   37898400
# 101  2014-05-30   527.11   567.8400   503.3000   559.89   36527700
# 102  2014-04-30   558.71   604.8300   502.8000   526.66   67171200
#
# [103 rows x 6 columns]

# %% [markdown]
# ### Cotações

# %%
acoes = ['ITUB4', 'ABEV3', 'BBAS3']

compilada = pd.DataFrame()

for acao in acoes:
    url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={acao}.SAO&apikey={chave_api}&datatype=csv'
    r = requests.get(url)
    tabela = pd.read_csv(StringIO(r.text))
    lista_tabelas = [compilada, tabela]
    compilada = pd.concat(lista_tabelas)
    
display(compilada)
# Out:
#       symbol   open   high    low  price    volume   latestDay  previousClose  \
# 0  ITUB4.SAO  28.75  29.17  28.50  28.65  40087100  2022-10-14          28.64
# 0  ABEV3.SAO  15.02  15.12  14.79  14.83  16936000  2022-10-14          15.01
# 0  BBAS3.SAO  39.66  40.18  38.68  39.16  12435500  2022-10-14          39.38
#
#    change changePercent
# 0    0.01       0.0349%
# 0   -0.18      -1.1992%
# 0   -0.22      -0.5587%

# %% [markdown]
# ### Encontrar ativos

# %%
url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=amazon&apikey={chave_api}&datatype=csv'
r = requests.get(url)

tabela = pd.read_csv(StringIO(r.text))
display(tabela)
# Out:
#        symbol                    name    type            region marketOpen  \
# 0        AMZN          Amazon.com Inc  Equity     United States      09:30
# 1     AMZ.DEX          Amazon.com Inc  Equity             XETRA      08:00
# 2     AMZ.FRK          Amazon.com Inc  Equity         Frankfurt      08:00
# 3  AMZO34.SAO          Amazon.com Inc  Equity  Brazil/Sao Paolo      10:00
# 4    0R1O.LON         Amazon.com Inc.  Equity    United Kingdom      08:00
# 5        AZFL  Amazonas Florestal Ltd  Equity     United States      09:30
#
#   marketClose timezone currency  matchScore
# 0       16:00   UTC-04      USD      0.8000
# 1       20:00   UTC+02      EUR      0.6000
# 2       20:00   UTC+02      EUR      0.6000
# 3       17:30   UTC-03      BRL      0.6000
# 4       16:30   UTC+01      USD      0.5714
# 5       16:00   UTC-04      USD      0.4286

# %% [markdown]
# ### Informações de Resultado

# %%
url = f'https://www.alphavantage.co/query?function=EARNINGS&symbol=AMZN&apikey={chave_api}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'symbol': 'AMZN', 'annualEarnings': [{'fiscalDateEnding': '2022-09-30', 'reportedEPS': '-0.58'}, {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '3.25'}, {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '6.86'}, {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '23.01'}, {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '20.13'}, {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '4.56'}, {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '4.91'}, {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '1.24'}, {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '-0.54'}, {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '0.58'}, {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '0.42'}, {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '1.37'}, {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '2.53'}, {'fiscalDateEnding': '2009-12-31', 'reportedEPS': '2.03'}, {'fiscalDateEnding': '2008-12-31', 'reportedEPS': '1.5'}, {'fiscalDateEnding': '2007-12-31', 'reportedEPS': '1.12'}, {'fiscalDateEnding': '2006-12-31', 'reportedEPS': '0.45'}, {'fiscalDateEnding': '2005-12-31', 'reportedEPS': '0.84'}, {'fiscalDateEnding': '2004-12-31', 'reportedEPS': '0.93'}, {'fiscalDateEnding': '2003-12-31', 'reportedEPS': '0.6'}, {'fiscalDateEnding': '2002-12-31', 'reportedEPS': '0.0776'}, {'fiscalDateEnding': '2001-12-31', 'reportedEPS': '-0.44'}, {'fiscalDateEnding': '2000-12-31', 'reportedEPS': '-1.18'}, {'fiscalDateEnding': '1999-12-31', 'reportedEPS': '-1.17'}, {'fiscalDateEnding': '1998-12-31', 'reportedEPS': '-0.25'}, {'fiscalDateEnding': '1997-12-31', 'reportedEPS': '-0.08'}], 'quarterlyEarnings': [{'fiscalDateEnding': '2022-06-30', 'reportedDate': '2022-07-28', 'reportedEPS': '-0.2', 'estimatedEPS': '0.14', 'surprise': '-0.34', 'surprisePercentage': '-242.8571'}, {'fiscalDateEnding': '2022-03-31', 'reportedDate': '2022-04-28', 'reportedEPS': '-0.38', 'estimatedEPS': '0.42', 'surprise': '-0.8', 'surprisePercentage': '-190.4762'}, {'fiscalDateEnding': '2021-12-31', 'reportedDate': '2022-02-03', 'reportedEPS': '1.39', 'estimatedEPS': '0.18', 'surprise': '1.21', 'surprisePercentage': '672.2222'}, {'fiscalDateEnding': '2021-09-30', 'reportedDate': '2021-10-28', 'reportedEPS': '0.31', 'estimatedEPS': '0.45', 'surprise': '-0.14', 'surprisePercentage': '-31.1111'}, {'fiscalDateEnding': '2021-06-30', 'reportedDate': '2021-07-29', 'reportedEPS': '0.76', 'estimatedEPS': '0.62', 'surprise': '0.14', 'surprisePercentage': '22.5806'}, {'fiscalDateEnding': '2021-03-31', 'reportedDate': '2021-04-29', 'reportedEPS': '0.79', 'estimatedEPS': '0.48', 'surprise': '0.31', 'surprisePercentage': '64.5833'}, {'fiscalDateEnding': '2020-12-31', 'reportedDate': '2021-02-02', 'reportedEPS': '0.71', 'estimatedEPS': '0.36', 'surprise': '0.35', 'surprisePercentage': '97.2222'}, {'fiscalDateEnding': '2020-09-30', 'reportedDate': '2020-10-29', 'reportedEPS': '0.62', 'estimatedEPS': '0.37', 'surprise': '0.25', 'surprisePercentage': '67.5676'}, {'fiscalDateEnding': '2020-06-30', 'reportedDate': '2020-07-30', 'reportedEPS': '0.52', 'estimatedEPS': '0.07', 'surprise': '0.45', 'surprisePercentage': '642.8571'}, {'fiscalDateEnding': '2020-03-31', 'reportedDate': '2020-04-30', 'reportedEPS': '5.01', 'estimatedEPS': '6.25', 'surprise': '-1.24', 'surprisePercentage': '-19.84'}, {'fiscalDateEnding': '2019-12-31', 'reportedDate': '2020-01-30', 'reportedEPS': '6.47', 'estimatedEPS': '4.03', 'surprise': '2.44', 'surprisePercentage': '60.5459'}, {'fiscalDateEnding': '2019-09-30', 'reportedDate': '2019-10-24', 'reportedEPS': '4.23', 'estimatedEPS': '4.62', 'surprise': '-0.39', 'surprisePercentage': '-8.4416'}, {'fiscalDateEnding': '2019-06-30', 'reportedDate': '2019-07-25', 'reportedEPS': '5.22', 'estimatedEPS': '5.57', 'surprise': '-0.35', 'surprisePercentage': '-6.2837'}, {'fiscalDateEnding': '2019-03-31', 'reportedDate': '2019-04-25', 'reportedEPS': '7.09', 'estimatedEPS': '4.72', 'surprise': '2.37', 'surprisePercentage': '50.2119'}, {'fiscalDateEnding': '2018-12-31', 'reportedDate': '2019-01- ...

# %%
import pprint
# pprint.pprint(data)

resultado = pd.DataFrame(data['annualEarnings'])
resultado
# Out:
#    fiscalDateEnding reportedEPS
# 0        2022-09-30       -0.58
# 1        2021-12-31        3.25
# 2        2020-12-31        6.86
# 3        2019-12-31       23.01
# 4        2018-12-31       20.13
# 5        2017-12-31        4.56
# 6        2016-12-31        4.91
# 7        2015-12-31        1.24
# 8        2014-12-31       -0.54
# 9        2013-12-31        0.58
# 10       2012-12-31        0.42
# 11       2011-12-31        1.37
# 12       2010-12-31        2.53
# 13       2009-12-31        2.03
# 14       2008-12-31         1.5
# 15       2007-12-31        1.12
# 16       2006-12-31        0.45
# 17       2005-12-31        0.84
# 18       2004-12-31        0.93
# 19       2003-12-31         0.6
# 20       2002-12-31      0.0776
# 21       2001-12-31       -0.44
# 22       2000-12-31       -1.18
# 23       1999-12-31       -1.17
# 24       1998-12-31       -0.25
# 25       1997-12-31       -0.08
