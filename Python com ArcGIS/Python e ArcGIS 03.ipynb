# %% [markdown]
# # Usando seu login e usuário no ArcGIS
#
# Link de Referência: https://developers.arcgis.com/python/guide/working-with-different-authentication-schemes/
#
# Funcionamento:

# %% [raw]
# gis = GIS('link', 'usuario', 'senha')

# %%
from arcgis.gis import GIS

print("Portal for ArcGIS as a built in user")
gis = GIS("https://portalname.domain.com/webadapter_name", "sharinguser", "password")
print("Logged in as: " + gis.properties.user.username)
# Out:
# Portal for ArcGIS as a built in user
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\envs\arcgispython3.7\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\anaconda3\envs\arcgispython3.7\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\envs\arcgispython3.7\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     751     addrlist = []
# --> 752     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...
