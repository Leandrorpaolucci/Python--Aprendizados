# %%
import pandas as pd

df = pd.read_csv(r'Pesquisas Eleitorais_I.csv', sep=',', encoding='utf-8')
display(df)
# Out:
#       id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 0            8023  2006      NaN            NaN  presidente  2006-09-19
# 1            8023  2006      NaN            NaN  presidente  2006-09-19
# 2            8023  2006      NaN            NaN  presidente  2006-09-19
# 3            8023  2006      NaN            NaN  presidente  2006-09-19
# 4            8023  2006      NaN            NaN  presidente  2006-09-19
# ...           ...   ...      ...            ...         ...         ...
# 9995         3975  2000       RS   Porto Alegre    prefeito  2000-05-11
# 9996         3976  2000       SP      São Paulo    prefeito  2000-05-11
# 9997         3976  2000       SP      São Paulo    prefeito  2000-05-11
# 9998         3976  2000       SP      São Paulo    prefeito  2000-05-11
# 9999         3976  2000       SP      São Paulo    prefeito  2000-05-11
#
#      data_referencia  instituto contratante orgao_registro  ...        tipo  \
# ...
